# %%
import matplotlib.pyplot as plt
import csv
import sys
plt.plot(( 1,2,3,4))
plt.ylabel(u'Alguns Números')
plt.show()

# %%
entrada = csv.reader (open('banco.csv '), delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-b19f9fa9e71b> in <module>()
# ----> 1 entrada = csv.reader (open('banco.csv '), delimiter=',')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'banco.csv '
